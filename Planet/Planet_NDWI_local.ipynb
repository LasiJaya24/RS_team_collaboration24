# %% [markdown]
# ### Import modules

# %%
import rasterio
from rasterio import plot as rasterplot
import numpy as np
import glob
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import fiona
import rasterio
import rasterio.mask
from rasterio.mask import mask
import numpy as np
import geopandas as gpd
from rasterio.plot import show
from rasterio.mask import mask
from shapely.geometry import mapping
import pandas as pd
import os
from xml.dom import minidom
from matplotlib import pyplot
from pyproj import CRS
from datetime import datetime
import imageio
from rasterio.transform import Affine
from rasterio.enums import ColorInterp

# %% [markdown]
# ### Set variables

# %%
# Planet images (seperate folder)
fileList = glob.glob(r"K:\Projects\_Job_Requests\241381_Ballangary_Analysis\Raw\images\*.tif")

# Waterbody crest shapefile
waterbody = r"K:\Projects\_Job_Requests\241381_Ballangary_Analysis\Raw\Ballangarry_Output\Surface_Ballangary_z55.shp"
#waterbody = r"K:\Projects\_Job_Requests\241381_Ballangary_Analysis\Outputs\Ballangarry_Reservoir_z55.shp"

# Output table
#csv = r'K:\Projects\_Job_Requests\241326_Stereoscopic_accuracy\planet\waterbody_114006000244055\results\waterbody_114006000244055_crest_results.csv'
#csv = r'K:\Projects\_Job_Requests\241326_Stereoscopic_accuracy\planet\waterbody_114006000244055\results\waterbody_114006000244055_topo_results.csv'
csv = r'K:\Projects\_Job_Requests\241381_Ballangary_Analysis\Outputs\timeseries_planet_crest.csv'

# Output raster
folder = r'K:\Projects\_Job_Requests\241381_Ballangary_Analysis\Outputs\Image_clips'

# NDWI threshold value
threshold = 0.0

# %% [markdown]
# ### Declare functions

# %%
def create_ndwi_4b(clip, output):

        # Load green and NIR bands - changed for 8 band
        with rasterio.open(clip) as src:
            band_grn = src.read(2)
        with rasterio.open(clip) as src:
            band_nir = src.read(4)

        # Allow division by zero
        np.seterr(divide='ignore', invalid='ignore')

        # Calculate NDWI. This is the equation at the top of this guide expressed in code
        ndwi = (band_nir.astype(float) - band_grn.astype(float)) / (band_nir + band_grn)
        
        # Set spatial characteristics of the output object to mirror the input
        kwargs = src.meta
        kwargs.update(
        dtype=rasterio.float32,
        count = 1)

        # Write band calculations to a new raster file (values over 0)
        with rasterio.open(output, 'w', **kwargs) as dst:
                dst.write_band(1, ndwi.astype(rasterio.float32))# Function to clip raster to shapefile
                
def clip_raster_to_shapefile(raster_file, shapefile, output_file):
    
    # Open shapefile using geopandas
    shp = gpd.read_file(shapefile)
    
    # Open raster file using rasterio
    with rasterio.open(raster_file) as src:
        #shp=shp.to_crs(src.crs)
        # print(Vector.crs)
        out_image, out_transform=mask(src,shp.geometry,crop=True)
        out_meta=src.meta.copy() # copy the metadata of the source DEM

    out_meta.update({
        "driver":"Gtiff",
        "height":out_image.shape[1], # height starts with shape[1]
        "width":out_image.shape[2], # width starts with shape[2]
        "transform":out_transform
    })

    with rasterio.open(output_file,'w',**out_meta) as dst:
        dst.write(out_image)    
    
# Function to classify raster into two classes based on a threshold
def classify_raster(raster_file, threshold, output_file):
    with rasterio.open(raster_file) as src:
        # Read raster band 1
        band1 = src.read(1)

        # Apply classification based on threshold
        classified = np.where(band1 <= threshold, 0, 1)

        # Update metadata
        out_meta = src.meta.copy()

    # Write the classified raster to a new file
    with rasterio.open(output_file, "w", **out_meta) as dest:
        dest.write(classified, 1)

# Function to measure the area of the raster above the threshold
def measure_area_above_threshold(raster_file, threshold):
    with rasterio.open(raster_file) as src:
        # Read raster band 1
        band1 = src.read(1)

        # Apply classification based on threshold
        classified = np.where(band1 < threshold, 1, 0)

        # Identify NoData values
        nodata = src.nodata

        # Exclude NoData values from calculation
        valid_values = np.logical_not(np.isnan(band1)) & np.logical_not(np.isclose(band1, nodata))

        # Calculate the area of cells above the threshold
        # Get the affine transformation
        transform = src.transform

        # Get the cell size in square meters
        x_res = transform[0]
        y_res = transform[4]
        cell_area_m2 = abs(x_res * y_res)

        # Calculate total area
        total_area = np.sum(valid_values) * cell_area_m2

        # Calculate area above threshold
        area_below_threshold = np.sum(classified) * cell_area_m2

        # Calculate percentage below threshold
        percentage_below_threshold = (area_below_threshold / total_area) * 100

    return total_area, area_below_threshold, percentage_below_threshold

# %% [markdown]
# ### Check projection and overlap

# %%
# Open shapefile using geopandas
shp = gpd.read_file(waterbody)

## reading the first tiff file:    
raster_image = rasterio.open(fileList[1])
tiff_band_1 = raster_image.read(1)

print('shapefile CRS: ', shp.crs)
print('image CRS: ', raster_image.crs)

if shp.crs != raster_image.crs:
    print('projections do not match')
    shp = shp.to_crs({'init': 'EPSG:32756'})    
    print('shapefile CRS: ', shp.crs)
    print('image CRS: ', raster_image.crs)
else:
    print('Projections match')
    
# Get raster extent
raster_extent = [raster_image.bounds[0], raster_image.bounds[2], raster_image.bounds[1], raster_image.bounds[3]]

# Create a new plot
f, ax = plt.subplots()

# plot DEM
rasterplot.show(
    tiff_band_1,  # use tiff.read(1) with your data
    extent=raster_extent,
    ax=ax,
)

# plot shapefiles
shp.plot(ax=ax, facecolor='w', edgecolor='k')
plt.savefig('test.jpg')
plt.show()

with rasterio.open(fileList[1]) as src:
    #shp=shp.to_crs(src.crs)
    # print(Vector.crs)
    out_image, out_transform=mask(src,shp.geometry,crop=True)
    out_meta=src.meta.copy() # copy the metadata of the source DEM
    
out_meta.update({
    "driver":"Gtiff",
    "height":out_image.shape[1], # height starts with shape[1]
    "width":out_image.shape[2], # width starts with shape[2]
    "transform":out_transform
})
# Out:
# shapefile CRS:  epsg:32755
# image CRS:  EPSG:32755
# Projections match

# %% [markdown]
# ### Loop through images

# %%
# Initialize empty DataFrame
df = pd.DataFrame(columns=["Image Name", "Image Date", "Total Area", "NDWI Area", "NDWI Percentage"])

# Loop through image folder
for image in fileList:
    
    # Get the image name and date
    image_name = os.path.basename(image)
    image_date = image_name[:8]
    image_date = datetime.strptime(image_date, '%Y%m%d').strftime('%d/%m/%Y')
    print("\nProcessing date: " + image_date)
    
    # create output file name
    clip = folder + "\\RGB_" + image_name[:8] + ".png"  
    output = folder + "\\NDWI_" + image_name[:8] + ".png"
    
    # Clip image
    try:
        print("Clipping image")
        clip_raster_to_shapefile(image, waterbody, clip)     
    except:      
        print("Clipping failed")
    
    # Create NDWI
    #try:   
    print("Creating NDWI")

    # Load green and NIR bands - changed for 4 band
    with rasterio.open(clip) as src:
        band_grn = src.read(2)
    with rasterio.open(clip) as src:
        band_nir = src.read(4)

    # Allow division by zero
    np.seterr(divide='ignore', invalid='ignore')

    # Calculate NDWI. This is the equation at the top of this guide expressed in code
    ndwi = (band_nir.astype(float) - band_grn.astype(float)) / (band_nir + band_grn)

    # Set spatial characteristics of the output object to mirror the input
    kwargs = src.meta
    kwargs.update(
    dtype=rasterio.float32,
    count = 1)

    # Define color map
    blue_color_map = {
        'blue': [(0, 1, 1), (1, 0, 0)]  # Blue color ramp from white to blue
    }

    # Define color interpretation
    color_interp = [ColorInterp.blue]

    # Create transformation matrix
    transform = Affine(30.0, 0.0, 0.0, 0.0, -30.0, 0.0)        

    # Write band calculations to a new raster file (values over 0)
    with rasterio.open(output, 'w', **kwargs) as dst:
            dst.write_colormap(1, blue_color_map)
            dst.write_band(1, ndwi.astype(rasterio.float32))
                
    #except:
    #    print("NDWI failed")
    
    # Measure surface area
    try:
        print("Measuring surface area")
        
        # Measure areas    
        total_area, area_above_threshold, percentage_above_threshold = measure_area_above_threshold(output, threshold)
        print("Total Area:", total_area, "square meters")
        print("NDWI Area:", area_above_threshold, "square meters")
        print("NDWI Percentage:", percentage_above_threshold, "%")

        # Append results to DataFrame
        df = df.append({
            "Image Name": image_name,
            "Image Date": image_date,
            "Total Area": total_area,
            "NDWI Area": area_above_threshold,
            "NDWI Percentage": percentage_above_threshold
        }, ignore_index=True)
            
    except:
        print("Area measurement failed")     
        
# Print DataFrame
print(df)

# Save DataFrame to CSV
df.to_csv(csv, index=False)

# Completion message
print("Completed")
# Out:
# Processing date: 04/12/2023
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033452.0 square meters
# NDWI Area: 887868.0 square meters
# NDWI Percentage: 85.91284355732051 %
#
# Processing date: 05/12/2023
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033848.0 square meters
# NDWI Area: 1031436.0 square meters
# NDWI Percentage: 99.7666968451842 %
#
# Processing date: 05/12/2023
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 07/12/2023
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033344.0 square meters
# NDWI Area: 876294.0 square meters
# NDWI Percentage: 84.80176978818284 %
#
# Processing date: 08/12/2023
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033839.0 square meters
# NDWI Area: 1030815.0 square meters
# NDWI Percentage: 99.70749797599045 %
#
# Processing date: 08/12/2023
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 10/12/2023
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033848.0 square meters
# NDWI Area: 1030626.0 square meters
# NDWI Percentage: 99.68834877080577 %
#
# Processing date: 10/12/2023
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 15/12/2023
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033839.0 square meters
# NDWI Area: 1024857.0 square meters
# NDWI Percentage: 99.13119934535261 %
#
# Processing date: 15/12/2023
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 17/12/2023
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033848.0 square meters
# NDWI Area: 1027998.0 square meters
# NDWI Percentage: 99.43415279615571 %
#
# Processing date: 17/12/2023
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 26/12/2023
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033821.0 square meters
# NDWI Area: 1027791.0 square meters
# NDWI Percentage: 99.41672688018525 %
#
# Processing date: 26/12/2023
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 27/12/2023
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033821.0 square meters
# NDWI Area: 1030086.0 square meters
# NDWI Percentage: 99.63871888847295 %
#
# Processing date: 27/12/2023
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 06/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033830.0 square meters
# NDWI Area: 1016478.0 square meters
# NDWI Percentage: 98.32158091755898 %
#
# Processing date: 06/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 11/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033830.0 square meters
# NDWI Area: 1010034.0 square meters
# NDWI Percentage: 97.69826760685993 %
#
# Processing date: 11/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 14/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033839.0 square meters
# NDWI Area: 1022625.0 square meters
# NDWI Percentage: 98.91530499429794 %
#
# Processing date: 14/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 19/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033821.0 square meters
# NDWI Area: 1021185.0 square meters
# NDWI Percentage: 98.77773811907477 %
#
# Processing date: 19/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 20/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033812.0 square meters
# NDWI Area: 1012689.0 square meters
# NDWI Percentage: 97.95678517951039 %
#
# Processing date: 20/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 21/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033857.0 square meters
# NDWI Area: 1013031.0 square meters
# NDWI Percentage: 97.98560149034151 %
#
# Processing date: 21/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 23/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033848.0 square meters
# NDWI Area: 1015542.0 square meters
# NDWI Percentage: 98.22933351904729 %
#
# Processing date: 23/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 24/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033812.0 square meters
# NDWI Area: 1009980.0 square meters
# NDWI Percentage: 97.69474527283491 %
#
# Processing date: 24/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 25/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033776.0 square meters
# NDWI Area: 1003941.0 square meters
# NDWI Percentage: 97.11397826995403 %
#
# Processing date: 25/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 27/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033866.0 square meters
# NDWI Area: 1033047.0 square meters
# NDWI Percentage: 99.9207827706879 %
#
# Processing date: 27/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 31/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033830.0 square meters
# NDWI Area: 1019430.0 square meters
# NDWI Percentage: 98.60712109340994 %
#
# Processing date: 31/01/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 01/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033848.0 square meters
# NDWI Area: 1023003.0 square meters
# NDWI Percentage: 98.95100633748868 %
#
# Processing date: 01/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 01/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033848.0 square meters
# NDWI Area: 1022535.0 square meters
# NDWI Percentage: 98.90573856118114 %
#
# Processing date: 01/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 09/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033866.0 square meters
# NDWI Area: 1029231.0 square meters
# NDWI Percentage: 99.55168271323362 %
#
# Processing date: 09/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 12/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033866.0 square meters
# NDWI Area: 1031121.0 square meters
# NDWI Percentage: 99.73449170395389 %
#
# Processing date: 12/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 14/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033821.0 square meters
# NDWI Area: 1024902.0 square meters
# NDWI Percentage: 99.13727811681132 %
#
# Processing date: 14/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 15/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033848.0 square meters
# NDWI Area: 1030149.0 square meters
# NDWI Percentage: 99.64221046033846 %
#
# Processing date: 15/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 16/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033866.0 square meters
# NDWI Area: 1032003.0 square meters
# NDWI Percentage: 99.81980256629002 %
#
# Processing date: 16/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 17/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033839.0 square meters
# NDWI Area: 1028700.0 square meters
# NDWI Percentage: 99.5029206675314 %
#
# Processing date: 17/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 19/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033812.0 square meters
# NDWI Area: 1021257.0 square meters
# NDWI Percentage: 98.7855625587631 %
#
# Processing date: 19/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 21/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033821.0 square meters
# NDWI Area: 1028430.0 square meters
# NDWI Percentage: 99.47853641974771 %
#
# Processing date: 21/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 22/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033848.0 square meters
# NDWI Area: 1029501.0 square meters
# NDWI Percentage: 99.57953200083571 %
#
# Processing date: 22/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 23/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033857.0 square meters
# NDWI Area: 1030068.0 square meters
# NDWI Percentage: 99.63350830917622 %
#
# Processing date: 23/02/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 01/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033857.0 square meters
# NDWI Area: 1028493.0 square meters
# NDWI Percentage: 99.48116615740862 %
#
# Processing date: 01/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 04/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033830.0 square meters
# NDWI Area: 1020087.0 square meters
# NDWI Percentage: 98.67067119352312 %
#
# Processing date: 04/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 05/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033839.0 square meters
# NDWI Area: 1028385.0 square meters
# NDWI Percentage: 99.47245170669707 %
#
# Processing date: 05/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 06/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033857.0 square meters
# NDWI Area: 1024371.0 square meters
# NDWI Percentage: 99.08246498306825 %
#
# Processing date: 06/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 10/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033812.0 square meters
# NDWI Area: 1016235.0 square meters
# NDWI Percentage: 98.29978758226834 %
#
# Processing date: 10/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 11/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033848.0 square meters
# NDWI Area: 1028637.0 square meters
# NDWI Percentage: 99.4959607214987 %
#
# Processing date: 11/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 12/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033794.0 square meters
# NDWI Area: 1023768.0 square meters
# NDWI Percentage: 99.03017429004231 %
#
# Processing date: 12/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 13/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033803.0 square meters
# NDWI Area: 1014543.0 square meters
# NDWI Percentage: 98.13697580680265 %
#
# Processing date: 13/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 14/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033812.0 square meters
# NDWI Area: 1021950.0 square meters
# NDWI Percentage: 98.85259602326148 %
#
# Processing date: 14/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 15/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033848.0 square meters
# NDWI Area: 1028916.0 square meters
# NDWI Percentage: 99.52294728045128 %
#
# Processing date: 15/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 16/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033794.0 square meters
# NDWI Area: 1022112.0 square meters
# NDWI Percentage: 98.86998763776923 %
#
# Processing date: 16/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 17/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033866.0 square meters
# NDWI Area: 1025370.0 square meters
# NDWI Percentage: 99.17823006076223 %
#
# Processing date: 17/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 18/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033785.0 square meters
# NDWI Area: 1018224.0 square meters
# NDWI Percentage: 98.49475471205328 %
#
# Processing date: 18/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 29/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033839.0 square meters
# NDWI Area: 1029339.0 square meters
# NDWI Percentage: 99.56472913093818 %
#
# Processing date: 29/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 30/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033866.0 square meters
# NDWI Area: 1030788.0 square meters
# NDWI Percentage: 99.70228250082698 %
#
# Processing date: 30/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 31/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033857.0 square meters
# NDWI Area: 1031742.0 square meters
# NDWI Percentage: 99.79542625334065 %
#
# Processing date: 31/03/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 06/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033866.0 square meters
# NDWI Area: 1033389.0 square meters
# NDWI Percentage: 99.95386249281822 %
#
# Processing date: 06/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 07/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033857.0 square meters
# NDWI Area: 1031769.0 square meters
# NDWI Percentage: 99.79803783308523 %
#
# Processing date: 07/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 08/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033821.0 square meters
# NDWI Area: 1029474.0 square meters
# NDWI Percentage: 99.57952101959624 %
#
# Processing date: 08/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033704.0 square meters
# NDWI Area: 916362.0 square meters
# NDWI Percentage: 88.64839451138818 %
#
# Processing date: 08/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 09/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033830.0 square meters
# NDWI Area: 1026765.0 square meters
# NDWI Percentage: 99.31661878645424 %
#
# Processing date: 09/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033542.0 square meters
# NDWI Area: 909135.0 square meters
# NDWI Percentage: 87.96304359184242 %
#
# Processing date: 09/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 12/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1030671.0 square meters
# NDWI Area: 810549.0 square meters
# NDWI Percentage: 78.6428452920476 %
#
# Processing date: 13/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1032471.0 square meters
# NDWI Area: 36702.0 square meters
# NDWI Percentage: 3.5547729669889034 %
#
# Processing date: 13/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1027791.0 square meters
# NDWI Area: 587241.0 square meters
# NDWI Percentage: 57.13622711232147 %
#
# Processing date: 14/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1028088.0 square meters
# NDWI Area: 621441.0 square meters
# NDWI Percentage: 60.4462847538343 %
#
# Processing date: 16/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033866.0 square meters
# NDWI Area: 1033173.0 square meters
# NDWI Percentage: 99.9329700367359 %
#
# Processing date: 16/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 17/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1028376.0 square meters
# NDWI Area: 687402.0 square meters
# NDWI Percentage: 66.84345025554855 %
#
# Processing date: 19/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1029600.0 square meters
# NDWI Area: 736191.0 square meters
# NDWI Percentage: 71.50262237762239 %
#
# Processing date: 19/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1029330.0 square meters
# NDWI Area: 733968.0 square meters
# NDWI Percentage: 71.30541225845938 %
#
# Processing date: 22/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033866.0 square meters
# NDWI Area: 1033803.0 square meters
# NDWI Percentage: 99.99390636697599 %
#
# Processing date: 22/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#
# Processing date: 25/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Total Area: 1033866.0 square meters
# NDWI Area: 1033866.0 square meters
# NDWI Percentage: 100.0 %
#
# Processing date: 25/04/2024
# Clipping image
# Creating NDWI
# Measuring surface area
# Area measurement failed
#                                            Image Name  Image Date  Total Area  \
# 0   20231204_000541_82_2251_3B_AnalyticMS_SR_clip.tif  04/12/2023   1033452.0
# 1      20231205_000545_13_2482_3B_AnalyticMS_clip.tif  05/12/2023   1033848.0
# 2   20231207_002431_03_2414_3B_AnalyticMS_SR_clip.tif  07/12/2023   1033344.0
# 3      20231208_232251_66_24c5_3B_AnalyticMS_clip.tif  08/12/2023   1033839.0
# 4      20231210_232417_55_24b2_3B_AnalyticMS_clip.tif  10/12/2023   1033848.0
# ..                                                ...         ...         ...
# 59  20240417_001737_78_24e1_3B_AnalyticMS_SR_clip.tif  17/04/2024   1028376.0
# 60  20240419_002130_42_24c6_3B_AnalyticMS_SR_clip.tif  19/04/2024   1029600.0
# 61  20240419_002132_70_24c6_3B_AnalyticMS_SR_clip.tif  19/04/2024   1029330.0
# 62     20240422_002212_45_24ee_3B_AnalyticMS_clip.tif  22/04/2024   1033866.0
# 63     20240425_001943_51_24e0_3B_AnalyticMS_clip.tif  25/04/2024   1033866.0
#
#     NDWI Area  NDWI Percentage
# 0    887868.0        85.912844
# 1   1031436.0        99.766697
# 2    876294.0        84.801770
# 3   1030815.0        99.707498
# 4   1030626.0        99.688349
# ..        ...              ...
# 59   687402.0        66.843450
# 60   736191.0        71.502622
# 61   733968.0        71.305412
# 62  1033803.0        99.993906
# 63  1033866.0       100.000000
#
# [64 rows x 5 columns]
# Completed
